# %% [markdown]
# <a href="https://colab.research.google.com/github/hpayettepeterson/foodprint/blob/hannah_branch2/CO2_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Making dataframe from recipes_with_nutritional_info.json

# %% [markdown]
# ## Set up notebook

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# enter correct folder
# %cd /content/drive/MyDrive/Colab_Notebooks/foodprint.ai
# Out:
# /content/drive/MyDrive/Colab_Notebooks/foodprint.ai

# %% [markdown]
# ## Make df of recipes

# %%
# get dataset of recipes
import json

recipe_path = 'data/recipes_with_nutritional_info.json'
with open(recipe_path, 'r') as f:
    recipes = json.load(f)

recipes[0].keys()
# Out:
# dict_keys(['fsa_lights_per100g', 'id', 'ingredients', 'instructions', 'nutr_per_ingredient', 'nutr_values_per100g', 'partition', 'quantity', 'title', 'unit', 'url', 'weight_per_ingr'])

# %% [markdown]
# Info we need to keep in dataset: id, ingredients, title, weight_per_ingr, (for now not this but maybe add later: nutr_values_per100g). Can maybe add in more info later.
#
# I will make a df with these columns. Or should I make a df for each recipe so that each ingredient can be properly multiplied by weight?

# %%
# loop through all recipes to make lists of values for each key
ids_lst = []
ingredient_lst = []
titles_lst = []
weights_lst = []
urls_lst = []
for i in range(len(recipes)):
  ids_lst.append(recipes[i]['id'])
  ingredient_lst.append(recipes[i]['ingredients'])
  titles_lst.append(recipes[i]['title'])
  weights_lst.append(recipes[i]['weight_per_ingr'])
  urls_lst.append(recipes[i]['url'])

# %%
# make ingredients for each recipe into list of strings (might need to change this later to a list of lists)
for i in range(len(ingredient_lst)):
  for n in range(len(ingredient_lst[i])):
    ingredient = ingredient_lst[i][n]['text']
    ingredient_lst[i][n] = ingredient

len(ingredient_lst)
# Out:
# 51235

# %% [markdown]
# The dataframe below is mostly useful for visualizing the data. It is actually easier to manipulate the data using the lists

# %%
# make lists into df
import pandas as pd

recipes_df = pd.DataFrame(
    {'id': ids_lst,
     'dish_name': titles_lst,
     'ingredients': ingredient_lst,
     'weight_per_ingr': weights_lst,
     'url': urls_lst
    })

# now, each item of the ingredients list corresponds to the item with the same index in the weight per ingr list
recipes_df.head()
# Out:
#            id  ...                                                url
# 0  000095fc1d  ...  http://tastykitchen.com/recipes/breakfastbrunc...
# 1  00051d5b9d  ...  http://cookeatshare.com/recipes/salt-free-low-...
# 2  00059b093b  ...  http://tastykitchen.com/recipes/main-courses/h...
# 3  0005fc89f7  ...  http://allrecipes.com/recipe/shrimp-and-caper-...
# 4  0006ca31f4  ...  http://www.food.com/recipe/natural-peanut-butt...
#
# [5 rows x 5 columns]

# %%
# make list of total dish weights by summing ingredients
dish_weights = []

for i in range(len(weights_lst)):
  dish_weights.append(sum(weights_lst[i]))

len(dish_weights)
# Out:
# 51235

# %%
import numpy as np
dish_weights_arr = np.array(dish_weights)
len(dish_weights_arr)
# Out:
# 51235

# %%
recipes[3758]
# Out:
# {'fsa_lights_per100g': {'fat': 'orange',
#   'salt': 'green',
#   'saturates': 'orange',
#   'sugars': 'orange'},
#  'id': '12bc400a54',
#  'ingredients': ['wheat flour, white, all-purpose, unenriched',
#   'shortening, vegetable, household, composite',
#   'water, bottled, generic',
#   'salt, table',
#   'butter, without salt',
#   'apples, raw, with skin',
#   'spices, cinnamon, ground',
#   'spices, nutmeg, ground',
#   'wheat flour, white, all-purpose, unenriched',
#   'lemon juice, raw',
#   'sugars, brown',
#   'sugars, granulated'],
#  'instructions': [{'text': 'Roll crust in strips.'},
#   {'text': "Pat together in an 18' round x 18 inch deep pan."},
#   {'text': "Bake in 19'round x 19 inch deep cinder block oven at 350F (180C) to 400 degrees until done."}],
#  'nutr_per_ingredient': [{'fat': 1564.7109632,
#    'nrg': 581178.35776,
#    'pro': 16493.3308672,
#    'sat': 247.47979519999998,
#    'sod': 3193.28768,
#    'sug': 431.0938368},
#   {'fat': 59856.181756800004,
#    'nrg': 529287.43296,
#    'pro': 0.0,
#    'sat': 14956.561171199999,
#    'sod': 2394.96576,
#    'sug': 0.0},
#   {'fat': 0.0, 'nrg': 0.0, 'pro': 0.0, 'sat': 0.0, 'sod': 1056.0, 'sug': 0.0},
#   {'fat': 0.0,
#    'nrg': 0.0,
#    'pro': 0.0,
#    'sat': 0.0,
#    'sod': 87901.59367999999,
#    'sug': 0.0},
#   {'fat': 6622.3524816,
#    'nrg': 58540.58352,
#    'pro': 69.39957600000001,
#    'sat': 4122.253167839999,
#    'sod': 898.11216,
#    'sug': 4.898793599999999},
#   {'fat': 10009.2384,
#    'nrg': 3098097.6,
#    'pro': 15728.8032,
#    'sat': 1668.2064000000003,
#    'sod': 47663.04,
#    'sug': 619142.8896},
#   {'fat': 435.9019119999999,
#    'nrg': 86828.8486,
#    'pro': 1402.619862,
#    'sat': 121.27916099999999,
#    'sod': 3515.3379999999997,
#    'sug': 762.828346},
#   {'fat': 315069.6751976,
#    'nrg': 4555537.853999999,
#    'pro': 50674.935366399994,
#    'sat': 225086.9560624,
#    'sod': 138835.43936,
#    'sug': 25944.872730400002},
#   {'fat': 213.36967679999998,
#    'nrg': 79251.59423999999,
#    'pro': 2249.0905728,
#    'sat': 33.7472448,
#    'sod': 435.44831999999997,
#    'sug': 58.78552319999999},
#   {'fat': 8713.119999999999,
#    'nrg': 797472.0,
#    'pro': 12552.8,
#    'sat': 1447.2640000000001,
#    'sod': 29536.0,
#    'sug': 90823.20000000001},
#   {'fat': 0.0,
#    'nrg': 1206554.7199999997,
#    'pro': 381.0172799999999,
#    'sat': 0.0,
#    'sod': 88904.03199999999,
#    'sug': 308052.47088},
#   {'fat': 0.0,
#    'nrg': 2457561.456,
#    'pro': 0.0,
#    'sat': 0.0,
#    'sod': 6350.288,
#    'sug': 633758.7423999999}],
#  'nutr_values_per100g': {'energy': 114.98301252210683,
#   'fat': 3.4407299578178034,
#   'protein': 0.8510426975644614,
#   'salt': 0.008777052280419759,
#   'saturates': 2.1173803753568117,
#   'sugars': 14.353137354731423},
#  'partition': 'train',
#  'quantity': [{'text': '352'},
#   {'text': '132'},
#   {'text': '8 1/4'},
#   {'text': '1/2'},
#   {'text': '18'},
#   {'text': '320'},
#   {'text': '77 1/2'},
#   {'text': '1913'},
#   {'text': '48'},
#   {'text': '923'},
#   {'text': '700'},
#   {'text': '1400'}],
#  'title': "World's Largest Apple Pie",
#  'unit': [{'text': 'pound'},
#   {'text': 'pound'},
#   {'text': 'gallon'},
#   {'text': 'pound'},
#   {'text': 'pound'},
#   {'text': 'bushel'},
#   {'text': 'pound'},
#   {'text': 'pound'},
#   {'text': 'pound'},
#   {'text': 'gallon'},
#   {'text': 'pound'},
#   {'text': 'pound'}],
#  'url': 'https://recipeland.com/recipe/v/worlds-largest-apple-pie-43107',
#  'weight_per_ingr': [159664.384,
#   59874.144,
#   31257.600000000002,
#   226.796,
#   8164.656,
#   5957880.0,
#   35153.38,
#   867721.4959999999,
#   21772.415999999997,
#   3603392.0,
#   317514.39999999997,
#   635028.7999999999]}

# %%
ingredient_lst[0]
# Out:
# ['yogurt, greek, plain, nonfat',
#  'strawberries, raw',
#  'cereals ready-to-eat, granola, homemade']

# %%
# create new column with total weight of dish (I think units are in grams?)
recipes_df['total_dish_weight'] = dish_weights
recipes_df.head()
# Out:
#            id  ... total_dish_weight
# 0  000095fc1d  ...        409.296000
# 1  00051d5b9d  ...        747.808333
# 2  00059b093b  ...       1579.409333
# 3  0005fc89f7  ...       1574.431917
# 4  0006ca31f4  ...       5356.000000
#
# [5 rows x 6 columns]

# %%
ingredient_lst[0]
# Out:
# ['yogurt, greek, plain, nonfat',
#  'strawberries, raw',
#  'cereals ready-to-eat, granola, homemade']

# %% [markdown]
# # Make df of co2 info

# %%
# load csv
co2_df = pd.read_csv('table_co2_v2.csv')

# %%
lettuce_df = pd.DataFrame({'ingredients': ['lettuce'], 'category': ['vegetables'], 'C02_per_kilo': [0.6]})
lettuce_df
# Out:
#   ingredients    category  C02_per_kilo
# 0     lettuce  vegetables           0.6

# %%
co2_df = co2_df.append(lettuce_df)
co2_df.tail()
# Out:
#             ingredients    category  C02_per_kilo
# 3517       zitronensaft       juice          1.72
# 3518           zucchini  vegetables          1.60
# 3519  zucchini blossoms  vegetables          1.60
# 3520   zucchini noodles     noodles          1.24
# 0               lettuce  vegetables          0.60

# %%
co2_df.head()
# Out:
#        ingredients category  C02_per_kilo
# 0     tomato sauce   sauces           1.6
# 1     tomato paste   sauces           1.6
# 2  american cheese   cheese          11.3
# 3       beef broth    broth           0.5
# 4    chicken broth    broth           0.5

# %% [markdown]
# ## Add in vegetarian info

# %%
co2_df['category'].unique()
# Out:
# array(['sauces', 'cheese', 'broth', 'vegetables', 'spices', 'pig', 'beer',
#        'milk', 'eggs', 'chicken', 'rice', 'coconut', 'mayonnaise',
#        'greenspices', 'nuts', 'sausage', 'turkey', 'noodles', 'cow',
#        'fish', 'juice', 'corn', 'mushrooms', 'booze', 'pulses', 'flour',
#        'fats', 'fruit', 'oil', 'seeds', 'wine', 'starchy roots', 'bread',
#        'other', 'other_animals', 'soft drinks', 'sugar', 'other_drinks',
#        'Poultry_meat', 'vegan', 'lamb', 'aquatic plants'], dtype=object)

# %%
co2_df['dietary_info']= co2_df['category'].apply(lambda x: 'non-veg' if (x == 'pig' or x == 'chicken' or x == 'sausage' or x == 'turkey' or x == 'cow' or x == 'fish' or x == 'other_animals' or x == 'Poultry_meat' or x == 'lamb') else 'vegetarian') 
co2_df.head(50)
# Out:
#                                ingredients  ... dietary_info
# 0                             tomato sauce  ...   vegetarian
# 1                             tomato paste  ...   vegetarian
# 2                          american cheese  ...   vegetarian
# 3                               beef broth  ...   vegetarian
# 4                            chicken broth  ...   vegetarian
# 5         condensed cream of mushroom soup  ...   vegetarian
# 6                           diced tomatoes  ...   vegetarian
# 7   to  lb chicken cut into serving pieces  ...   vegetarian
# 8                          vegetable broth  ...   vegetarian
# 9                                    bacon  ...      non-veg
# 10                          barbecue sauce  ...   vegetarian
# 11                           beef bouillon  ...   vegetarian
# 12                  beef bouillon granules  ...   vegetarian
# 13                              beef broth  ...   vegetarian
# 14             beef flavored bouillon cube  ...   vegetarian
# 15                              beef stock  ...   vegetarian
# 16                                    beer  ...   vegetarian
# 17                             black beans  ...   vegetarian
# 18                           bouillon cube  ...   vegetarian
# 19                                   broth  ...   vegetarian
# 20                              buttermilk  ...   vegetarian
# 21                          cage free eggs  ...   vegetarian
# 22                                 carrots  ...   vegetarian
# 23                          cheddar cheese  ...   vegetarian
# 24                         chicken breasts  ...      non-veg
# 25                           chicken broth  ...   vegetarian
# 26                 chicken flavor bouillon  ...   vegetarian
# 27            chicken flavor bouillon cube  ...   vegetarian
# 28               chicken flavor rice sides  ...   vegetarian
# 29                           chicken stock  ...   vegetarian
# 30                       chipotle minicube  ...   vegetarian
# 31                 classic brown gravy mix  ...   vegetarian
# 32                                 coconut  ...   vegetarian
# 33                          coconut flakes  ...   vegetarian
# 34                            coconut milk  ...   vegetarian
# 35         condensed cream of chicken soup  ...   vegetarian
# 36                           cooking spray  ...   vegetarian
# 37                          cottage cheese  ...   vegetarian
# 38                            cream cheese  ...   vegetarian
# 39                    cream of celery soup  ...   vegetarian
# 40                  cream of mushroom soup  ...   vegetarian
# 41                    creamy peanut butter  ...   vegetarian
# 42                    crumbled feta cheese  ...   vegetarian
# 43                                deli ham  ...      non-veg
# 44                                dry milk  ...   vegetarian
# 45                              egg whites  ...   vegetarian
# 46                               egg yolks  ...   vegetarian
# 47                                    eggs  ...   vegetarian
# 48                         evaporated milk  ...   vegetarian
# 49               fat skimmed chicken broth  ...   vegetarian
#
# [50 rows x 4 columns]

# %%
co2_df.head(50)
# Out:
#                                ingredients  ... dietary_info
# 0                             tomato sauce  ...   vegetarian
# 1                             tomato paste  ...   vegetarian
# 2                          american cheese  ...   vegetarian
# 3                               beef broth  ...   vegetarian
# 4                            chicken broth  ...   vegetarian
# 5         condensed cream of mushroom soup  ...   vegetarian
# 6                           diced tomatoes  ...   vegetarian
# 7   to  lb chicken cut into serving pieces  ...   vegetarian
# 8                          vegetable broth  ...   vegetarian
# 9                                    bacon  ...      non-veg
# 10                          barbecue sauce  ...   vegetarian
# 11                           beef bouillon  ...   vegetarian
# 12                  beef bouillon granules  ...   vegetarian
# 13                              beef broth  ...   vegetarian
# 14             beef flavored bouillon cube  ...   vegetarian
# 15                              beef stock  ...   vegetarian
# 16                                    beer  ...   vegetarian
# 17                             black beans  ...   vegetarian
# 18                           bouillon cube  ...   vegetarian
# 19                                   broth  ...   vegetarian
# 20                              buttermilk  ...   vegetarian
# 21                          cage free eggs  ...   vegetarian
# 22                                 carrots  ...   vegetarian
# 23                          cheddar cheese  ...   vegetarian
# 24                         chicken breasts  ...      non-veg
# 25                           chicken broth  ...   vegetarian
# 26                 chicken flavor bouillon  ...   vegetarian
# 27            chicken flavor bouillon cube  ...   vegetarian
# 28               chicken flavor rice sides  ...   vegetarian
# 29                           chicken stock  ...   vegetarian
# 30                       chipotle minicube  ...   vegetarian
# 31                 classic brown gravy mix  ...   vegetarian
# 32                                 coconut  ...   vegetarian
# 33                          coconut flakes  ...   vegetarian
# 34                            coconut milk  ...   vegetarian
# 35         condensed cream of chicken soup  ...   vegetarian
# 36                           cooking spray  ...   vegetarian
# 37                          cottage cheese  ...   vegetarian
# 38                            cream cheese  ...   vegetarian
# 39                    cream of celery soup  ...   vegetarian
# 40                  cream of mushroom soup  ...   vegetarian
# 41                    creamy peanut butter  ...   vegetarian
# 42                    crumbled feta cheese  ...   vegetarian
# 43                                deli ham  ...      non-veg
# 44                                dry milk  ...   vegetarian
# 45                              egg whites  ...   vegetarian
# 46                               egg yolks  ...   vegetarian
# 47                                    eggs  ...   vegetarian
# 48                         evaporated milk  ...   vegetarian
# 49               fat skimmed chicken broth  ...   vegetarian
#
# [50 rows x 4 columns]

# %%
# properly categorize other types of food eg broth
# chicken
mask = co2_df['ingredients'].str.contains(r'chicken', na=True)
co2_df.loc[mask, 'dietary_info'] = 'non-veg'
co2_df.head(50)
# Out:
#                                ingredients  ... dietary_info
# 0                             tomato sauce  ...   vegetarian
# 1                             tomato paste  ...   vegetarian
# 2                          american cheese  ...   vegetarian
# 3                               beef broth  ...   vegetarian
# 4                            chicken broth  ...      non-veg
# 5         condensed cream of mushroom soup  ...   vegetarian
# 6                           diced tomatoes  ...   vegetarian
# 7   to  lb chicken cut into serving pieces  ...      non-veg
# 8                          vegetable broth  ...   vegetarian
# 9                                    bacon  ...      non-veg
# 10                          barbecue sauce  ...   vegetarian
# 11                           beef bouillon  ...   vegetarian
# 12                  beef bouillon granules  ...   vegetarian
# 13                              beef broth  ...   vegetarian
# 14             beef flavored bouillon cube  ...   vegetarian
# 15                              beef stock  ...   vegetarian
# 16                                    beer  ...   vegetarian
# 17                             black beans  ...   vegetarian
# 18                           bouillon cube  ...   vegetarian
# 19                                   broth  ...   vegetarian
# 20                              buttermilk  ...   vegetarian
# 21                          cage free eggs  ...   vegetarian
# 22                                 carrots  ...   vegetarian
# 23                          cheddar cheese  ...   vegetarian
# 24                         chicken breasts  ...      non-veg
# 25                           chicken broth  ...      non-veg
# 26                 chicken flavor bouillon  ...      non-veg
# 27            chicken flavor bouillon cube  ...      non-veg
# 28               chicken flavor rice sides  ...      non-veg
# 29                           chicken stock  ...      non-veg
# 30                       chipotle minicube  ...   vegetarian
# 31                 classic brown gravy mix  ...   vegetarian
# 32                                 coconut  ...   vegetarian
# 33                          coconut flakes  ...   vegetarian
# 34                            coconut milk  ...   vegetarian
# 35         condensed cream of chicken soup  ...      non-veg
# 36                           cooking spray  ...   vegetarian
# 37                          cottage cheese  ...   vegetarian
# 38                            cream cheese  ...   vegetarian
# 39                    cream of celery soup  ...   vegetarian
# 40                  cream of mushroom soup  ...   vegetarian
# 41                    creamy peanut butter  ...   vegetarian
# 42                    crumbled feta cheese  ...   vegetarian
# 43                                deli ham  ...      non-veg
# 44                                dry milk  ...   vegetarian
# 45                              egg whites  ...   vegetarian
# 46                               egg yolks  ...   vegetarian
# 47                                    eggs  ...   vegetarian
# 48                         evaporated milk  ...   vegetarian
# 49               fat skimmed chicken broth  ...      non-veg
#
# [50 rows x 4 columns]

# %%
# beef
mask = co2_df['ingredients'].str.contains(r'beef', na=True)
co2_df.loc[mask, 'dietary_info'] = 'non-veg'
# duck
mask2 = co2_df['ingredients'].str.contains(r'duck', na=True)
co2_df.loc[mask2, 'dietary_info'] = 'non-veg'
# pork
mask3 = co2_df['ingredients'].str.contains(r'pork', na=True)
co2_df.loc[mask3, 'dietary_info'] = 'non-veg'
# lamb
mask4 = co2_df['ingredients'].str.contains(r'lamb', na=True)
co2_df.loc[mask4, 'dietary_info'] = 'non-veg'
# fish
mask5 = co2_df['ingredients'].str.contains(r'fish', na=True)
co2_df.loc[mask5, 'dietary_info'] = 'non-veg'
# animal fats
mask6 = co2_df['ingredients'].str.contains(r'animal fats', na=True)
co2_df.loc[mask6, 'dietary_info'] = 'non-veg'

co2_df.head(50)
# Out:
#                                ingredients  ... dietary_info
# 0                             tomato sauce  ...   vegetarian
# 1                             tomato paste  ...   vegetarian
# 2                          american cheese  ...   vegetarian
# 3                               beef broth  ...      non-veg
# 4                            chicken broth  ...      non-veg
# 5         condensed cream of mushroom soup  ...   vegetarian
# 6                           diced tomatoes  ...   vegetarian
# 7   to  lb chicken cut into serving pieces  ...      non-veg
# 8                          vegetable broth  ...   vegetarian
# 9                                    bacon  ...      non-veg
# 10                          barbecue sauce  ...   vegetarian
# 11                           beef bouillon  ...      non-veg
# 12                  beef bouillon granules  ...      non-veg
# 13                              beef broth  ...      non-veg
# 14             beef flavored bouillon cube  ...      non-veg
# 15                              beef stock  ...      non-veg
# 16                                    beer  ...   vegetarian
# 17                             black beans  ...   vegetarian
# 18                           bouillon cube  ...   vegetarian
# 19                                   broth  ...   vegetarian
# 20                              buttermilk  ...   vegetarian
# 21                          cage free eggs  ...   vegetarian
# 22                                 carrots  ...   vegetarian
# 23                          cheddar cheese  ...   vegetarian
# 24                         chicken breasts  ...      non-veg
# 25                           chicken broth  ...      non-veg
# 26                 chicken flavor bouillon  ...      non-veg
# 27            chicken flavor bouillon cube  ...      non-veg
# 28               chicken flavor rice sides  ...      non-veg
# 29                           chicken stock  ...      non-veg
# 30                       chipotle minicube  ...   vegetarian
# 31                 classic brown gravy mix  ...   vegetarian
# 32                                 coconut  ...   vegetarian
# 33                          coconut flakes  ...   vegetarian
# 34                            coconut milk  ...   vegetarian
# 35         condensed cream of chicken soup  ...      non-veg
# 36                           cooking spray  ...   vegetarian
# 37                          cottage cheese  ...   vegetarian
# 38                            cream cheese  ...   vegetarian
# 39                    cream of celery soup  ...   vegetarian
# 40                  cream of mushroom soup  ...   vegetarian
# 41                    creamy peanut butter  ...   vegetarian
# 42                    crumbled feta cheese  ...   vegetarian
# 43                                deli ham  ...      non-veg
# 44                                dry milk  ...   vegetarian
# 45                              egg whites  ...   vegetarian
# 46                               egg yolks  ...   vegetarian
# 47                                    eggs  ...   vegetarian
# 48                         evaporated milk  ...   vegetarian
# 49               fat skimmed chicken broth  ...      non-veg
#
# [50 rows x 4 columns]

# %%
# make list of all diet info
dietary_info_lst = co2_df['dietary_info'].tolist()
len(dietary_info_lst)
# Out:
# 3522

# %% [markdown]
# ## Add more columns

# %%
co2_df["CO2_per_kilo"] = pd.to_numeric(co2_df["C02_per_kilo"], downcast="float") # change co2 per kilo to float
co2_df.drop(columns='C02_per_kilo', inplace=True) # fix column naming

co2_df.head()
# Out:
#        ingredients category dietary_info  CO2_per_kilo
# 0     tomato sauce   sauces   vegetarian           1.6
# 1     tomato paste   sauces   vegetarian           1.6
# 2  american cheese   cheese   vegetarian          11.3
# 3       beef broth    broth      non-veg           0.5
# 4    chicken broth    broth      non-veg           0.5

# %%
# create co2 per gram column
co2_df['CO2_per_gram'] = co2_df['CO2_per_kilo'] / 1000
co2_df.head()
# Out:
#        ingredients category dietary_info  CO2_per_kilo  CO2_per_gram
# 0     tomato sauce   sauces   vegetarian           1.6        0.0016
# 1     tomato paste   sauces   vegetarian           1.6        0.0016
# 2  american cheese   cheese   vegetarian          11.3        0.0113
# 3       beef broth    broth      non-veg           0.5        0.0005
# 4    chicken broth    broth      non-veg           0.5        0.0005

# %%
# make list of all ingredients
all_ingredients = co2_df['ingredients'].tolist()
len(all_ingredients)
# Out:
# 3522

# %%
# make list of co2 values per ingredient
co2_per_gram = co2_df['CO2_per_gram'].tolist()
len(co2_per_gram)
# Out:
# 3522

# %% [markdown]
# # Calculating CO2 per ingredient

# %%
# checking format of ingredients
ingredient_lst[0]
# Out:
# ['yogurt, greek, plain, nonfat',
#  'strawberries, raw',
#  'cereals ready-to-eat, granola, homemade']

# %% [markdown]
# ## Calculate carbon footprint per ingredient

# %%
# calculate carbon footprint per ingredient

footprints_per_dish = [] # list of lists of co2 per ingredient
all_dietary_info = []

for recipe_number, ingredients in enumerate(ingredient_lst): # get the list of ingredients of each recipe
  footprints_lst = []
  diet_lst = []
  for ingr_number, ingredient in enumerate(ingredients): # get each single ingredient
    for food_index, food in enumerate(all_ingredients): # go thru foods we are searching for
      if len(footprints_lst) != (ingr_number): # check if there is no match for ingredient
        footprints_lst.append(False) # mark ingredient as unmatched
      if food in ingredient: # see if food is in ingredients
        footprint_per_ingr = weights_lst[recipe_number][ingr_number] * co2_per_gram[food_index] # multiply to get co2 per ingredient
        footprints_lst.append(footprint_per_ingr) # make list of ingr footprints for each dish
        diet_lst.append(dietary_info_lst[food_index])
        break # get only one match per ingredient 
    if len(footprints_lst) == (ingr_number - 1):
      footprints_lst.append(False)  
  footprints_per_dish.append(footprints_lst) # make list of lists for footprint per ingredient
  all_dietary_info.append(diet_lst)

  # total_footprint_for_dish = sum(footprints_lst)
  # dish_footprints.append(total_footprint_for_dish)

len(footprints_per_dish)
# Out:
# 51235

# %%
# add footprint per ingredient to df
recipes_df['footprints_per_ingredient'] = footprints_per_dish
recipes_df.head()
# Out:
#            id  ...                          footprints_per_ingredient
# 0  000095fc1d  ...  [0.3401940029570833, 0.13679999765008688, 0.04...
# 1  00051d5b9d  ...  [0.35280001088976864, 0.5040000043809414, 0.08...
# 2  00059b093b  ...  [6.123491736397146, 0.009600000455975533, 0.00...
# 3  0005fc89f7  ...  [4.898793727070093, 0.037500001781154424, 0.01...
# 4  0006ca31f4  ...    [False, 4.068000193219632, 0.29951998591423035]
#
# [5 rows x 7 columns]

# %%
# check if all ingredients are being accounted for
from collections import Counter
same_length_test = []
for i in range(len(recipes_df)):
  if len(recipes_df['ingredients'][i]) == len(recipes_df['footprints_per_ingredient'][i]):
    same_length_test.append(True)
  else:
    same_length_test.append(False)
Counter(same_length_test)
# Out:
# Counter({False: 3939, True: 47296})

# %%
# calculate footprint per ingredient for 100gr of dish, add to df
footprint_per_ingr_100gr_lst = []

for recipe_number, ingredients in enumerate(footprints_per_dish):
  footprints_lst = []
  for ingr_number, ingredient in enumerate(ingredients):
    if ingredient != False:
      footprint_per_ingr_100gr = (ingredient / dish_weights[recipe_number]) * 100 # footprint of each ingredient per gram, * 100 grams
      footprints_lst.append(footprint_per_ingr_100gr)
    else:
      footprints_lst.append(False)
  footprint_per_ingr_100gr_lst.append(footprints_lst)
recipes_df['footprint_per_ingr_100gr'] = footprint_per_ingr_100gr_lst
recipes_df.head()
# Out:
#            id  ...                           footprint_per_ingr_100gr
# 0  000095fc1d  ...  [0.08311686480128888, 0.03342324323963266, 0.0...
# 1  00051d5b9d  ...  [0.04717786565939605, 0.06739694944751103, 0.0...
# 2  00059b093b  ...  [0.3877077086453299, 0.0006078221936117596, 0....
# 3  0005fc89f7  ...  [0.31114674919965113, 0.0023818115844950697, 0...
# 4  0006ca31f4  ...  [False, 0.07595220674420522, 0.005592232746718...
#
# [5 rows x 8 columns]

# %%
len(recipes_df['footprint_per_ingr_100gr'][3990])
# Out:
# 17

# %%
# check if footprints per ingredient for 100gr of dish has preserved missing ingredient values
for i in range(len(footprint_per_ingr_100gr_lst)):
  if False in footprint_per_ingr_100gr_lst[i]:
    print(i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 30347
# 30349
# 30359
# 30366
# 30367
# 30371
# 30380
# 30387
# 30388
# 30390
# 30392
# 30393
# 30396
# 30398
# 30411
# 30413
# 30415
# 30420
# 30423
# 30437
# 30438
# 30439
# 30443
# 30446
# 30449
# 30452
# 30453
# 30457
# 30458
# 30459
# 30462
# 30470
# 30473
# 30486
# 30489
# 30492
# 30502
# 30510
# 30514
# 30515
# 30520
# 30521
# 30524
# 30526
# 30528
# 30529
# 30538
# 30541
# 30548
# 30553
# 30561
# 30571
# 30574
# 30575
# 30577
# 30579
# 30580
# 30582
# 30584
# 30591
# 30595
# 30599
# 30600
# 30602
# 30606
# 30608
# 30609
# 30621
# 30626
# 30629
# 30630
# 30631
# 30633
# 30634
# 30636
# 30643
# 30646
# 30654
# 30659
# 30663
# 30664
# 30665
# 30667
# 30668
# 30674
# 30681
# 30687
# 30690
# 30694
# 30697
# 30701
# 30707
# 30708
# 30719
# 30728
# 30735
# 30743
# 30744
# 30752
# 30754
# 30756
# 30757
# 30758
# 30760
# 30770
# 30771
# 30775
# 30776
# 30779
# 30787
# 30789
# 30804
# 30808
# 30810
# 30811
# 30815
# 30819
# 30821
# 30822
# 30823
# 30824
# 30826
# 30830
# 30832
# 30834
# 30836
# 30839
# 30843
# 30847
# 30848
# 30849
# 30861
# 30862
# 30864
# 30868
# 30871
# 30876
# 30881
# 30886
# 30889
# 30892
# 30894
# 30905
# 30910
# 30913
# 30916
# 30922
# 30926
# 30934
# 30939
# 30943
# 30952
# 30953
# 30954
# 30957
# 30961
# 30966
# 30968
# 30969
# 30972
# 30974
# 30977
# 30979
# 30986
# 30991
# 30992
# 30993
# 31013
# 31015
# 31020
# 31023
# 31024
# 31025
# 31027
# 31047
# 31050
# 31051
# 31059
# 31065
# 31066
# 31068
# 31071
# 31074
# 31081
# 31083
# 31084
# 31086
# 31089
# 31090
# 31091
# 31094
# 31096
# 31101
# 31103
# 31105
# 31112
# 31114
# 31118
# 31133
# 31136
# 31141
# 31145
# 31152
# 31165
# 31171
# 31172
# 31176
# 31180
# 31184
# 31185
# 31189
# 31192
# 31202
# 31207
# 31210
# 31211
# 31214
# 31216
# 31217
# 31228
# 31230
# 31231
# 31232
# 31241
# 31245
# 31246
# 31247
# 31249
# 31254
# 31256
# 31263
# 31264
# 31271
# 31275
# 31284
# 31293
# 31294
# 31295
# 31298
# 31300
# 31311
# 31320
# 31323
# 31324
# 31326
# 31328
# 31329
# 31338
# 31344
# 31345
# 31354
# 31359
# 31360
# 31361
# 31363
# 31367
# 31371
# 31376
# 31389
# 31391
# 31396
# 31399
# 31411
# 31416
# 31421
# 31435
# 31436
# 31440
# 31445
# 31450
# 31453
# 31462
# 31466
# 31469
# 31474
# 31475
# 31476
# 31484
# 31485
# 31491
# 31492
# 31498
# 31511
# 31524
# 31525
# 31529
# 31532
# 31533
# 31534
# 31538
# 31541
# 31542
# 31545
# 31546
# 31553
# 31557
# 31562
# 31563
# 31564
# 31566
# 31569
# 31570
# 31589
# 31590
# 31594
# 31596
# 31607
# 44123
# 44132
# 44146
# 44150
# 44153
# 44162
# 44176
# 44177
# 44178
# 44182
# 44192
# 44193
# 44196
# 44199
# 44202
# 44203
# 44209
# 44214
# 44217
# 44221
# 44229
# 44234
# 44238
# 44239
# 44244
# 44245
# 44248
# 44256
# 44261
# 44264
# 44267
# 44268
# 44270
# 44274
# 44276
# 44286
# 44287
# 44288
# 44301
# 44302
# 44303
# 44309
# 44323
# 44328
# 44330
# 44332
# 44333
# 44336
# 44338
# 44343
# 44344
# 44353
# 44355
# 44356
# 44357
# 44363
# 44374
# 44375
# 44387
# 44390
# 44391
# 44393
# 44399
# 44402
# 44404
# 44413
# 44419
# 44425
# 44430
# 44435
# 44437
# 44447
# 44453
# 44454
# 44455
# 44465
# 44469
# 44471
# 44472
# 44483
# 44502
# 44504
# 44508
# 44511
# 44513
# 44515
# 44520
# 44521
# 44526
# 44529
# 44530
# 44532
# 44534
# 44538
# 44549
# 44550
# 44552
# 44562
# 44565
# 44573
# 44582
# 44583
# 44585
# 44588
# 44590
# 44591
# 44603
# 44608
# 44614
# 44619
# 44635
# 44636
# 44638
# 44639
# 44641
# 44643
# 44644
# 44648
# 44649
# 44650
# 44656
# 44659
# 44665
# 44688
# 44693
# 44695
# 44702
# 44705
# 44707
# 44708
# 44709
# 44713
# 44716
# 44719
# 44724
# 44727
# 44729
# 44734
# 44743
# 44744
# 44747
# 44749
# 44755
# 44760
# 44762
# 44764
# 44765
# 44775
# 44776
# 44781
# 44788
# 44791
# 44795
# 44796
# 44799
# 44801
# 44804
# 44811
# 44813
# 44820
# 44824
# 44826
# 44830
# 44834
# 44840
# 44844
# 44852
# 44856
# 44858
# 44859
# 44863
# 44864
# 44867
# 44877
# 44879
# 44880
# 44883
# 44889
# 44893
# 44902
# 44906
# 44918
# 44919
# 44921
# 44925
# 44936
# 44937
# 44939
# 44953
# 44956
# 44958
# 44960
# 44965
# 44967
# 44968
# 44971
# 44974
# 44976
# 44978
# 44984
# 44992
# 44994
# 44995
# 45000
# 45002
# 45008
# 45013
# 45014
# 45016
# 45020
# 45027
# 45028
# 45036
# 45037
# 45039
# 45044
# 45048
# 45051
# 45054
# 45055
# 45056
# 45068
# 45069
# 45074
# 45077
# 45088
# 45089
# 45096
# 45097
# 45098
# 45103
# 45117
# 45121
# 45126
# 45134
# 45135
# 45136
# 45144
# 45146
# 45147
# 45150
# 45151
# 45152
# 45156
# 45157
# 45161
# 45163
# 45168
# 45171
# 45174
# 45176
# 45177
# 45178
# 45179
# 45184
# 45191
# 45195
# 45203
# 45204
# 45205
# 45210
# 45219
# 45222
# 45241
# 45244
# 45245
# 45248
# 45249
# 45257
# 45258
# 45259
# 45262
# 45265
# 45271
# 45272
# 45279
# 45282
# 45287
# 45289
# 45294
# 45300
# 45301
# 45307
# 45309
# 45310
# 45313
# 45314
# 45321
# 45323
# 45327
# 45329
# 45337
# 45339
# 45340
# 45341
# 45344
# 45347
# 45354
# 45356
# 45362
# 45363
# 45367
# 50561
# 50572
# 50573
# 50575
# 50579
# 50583
# 50594
# 50596
# 50613
# 50618
# 50620
# 50621
# 50624
# 50633
# 50637
# 50639
# 50642
# 50647
# 50651
# 50661
# 50666
# 50675
# 50677
# 50682
# 50687
# 50688
# 50689
# 50690
# 50692
# 50705
# 50712
# 50734
# 50736
# 50738
# 50739
# 50745
# 50750
# 50752
# 50757
# 50772
# 50782
# 50784
# 50795
# 50796
# 50797
# 50804
# 50807
# 50811
# 50818
# 50823
# 50825
# 50826
# 50828
# 50832
# 50833
# 50836
# 50837
# 50840
# 50856
# 50857
# 50860
# 50861
# 50862
# 50863
# 50868
# 50872
# 50873
# 50884
# 50887
# 50889
# 50890
# 50892
# 50893
# 50896
# 50904
# 50907
# 50912
# 50918
# 50925
# 50933
# 50939
# 50943
# 50944
# 50945
# 50949
# 50957
# 50959
# 50965
# 50979
# 50985
# 50986
# 50989
# 50991
# 50992
# 51002
# 51004
# 51008
# 51012
# 51017
# 51028
# 51039
# 51041
# 51042
# 51045
# 51050
# 51051
# 51054
# 51058
# 51063
# 51067
# 51073
# 51074
# 51079
# 51080
# 51081
# 51083
# 51084
# 51090
# 51108
# 51112
# 51113
# 51118
# 51122
# 51123
# 51126
# 51128
# 51129
# 51131
# 51132
# 51134
# 51136
# 51138
# 51139
# 51140
# 51145
# 51147
# 51153
# 51159
# 51161
# 51165
# 51167
# 51174
# 51185
# 51190
# 51193
# 51198
# 51199
# 51202
# 51204
# 51209
# 51211
# 51220
# 51224
# 51225
# 51226
# 51230
# 51231
# 51232
# 51233

# %% [markdown]
# ## Add in dietary info

# %%
# add dietary info to df
dietary_info_per_dish = []
for recipe_number, ingredients in enumerate(all_dietary_info):
  if 'non-veg' in ingredients:
    dietary_info_per_dish.append('non-veg')
  else:
    dietary_info_per_dish.append('vegetarian')

dietary_info_per_dish[:10]
# Out:
# ['vegetarian',
#  'vegetarian',
#  'non-veg',
#  'non-veg',
#  'vegetarian',
#  'vegetarian',
#  'vegetarian',
#  'vegetarian',
#  'vegetarian',
#  'vegetarian']

# %% [markdown]
# ## Calculate total footprint per dish & confidence scores

# %% [markdown]
# Confidence score is percentage of weight of the dish which is accounted for in our data

# %%
confidence_scores = [] # percentage of weight which is accounted for in our data
dish_footprints = [] # total footprint per each dish

for recipe_number, ingredients in enumerate(footprints_per_dish):
  if False in ingredients:
    ingr_number = ingredients.index(False)
    confidence_score = 1 - (weights_lst[recipe_number][ingr_number] / dish_weights[recipe_number]) # get percentage of total weight for unmatched ingredient
    ingredients.remove(False) # get rid of false
    total_footprint_for_dish = sum(ingredients) # get sum of ingredient footprints 
  else:
    confidence_score = 1
    total_footprint_for_dish = sum(ingredients)
  confidence_scores.append(confidence_score)
  dish_footprints.append(total_footprint_for_dish)

min(confidence_scores), max(confidence_scores), np.mean(confidence_scores)
# Out:
# (0.0004131962770465014, 1, 0.9594943002713006)

# %% [markdown]
# ## Get CO2 footprint per gram, per 100g and per kilo

# %%
dish_footprints_arr = np.array(dish_footprints)
dish_weights_arr = np.array(dish_weights)

dish_footprint_per_gr = dish_footprints_arr / dish_weights_arr # calculate dish footprint per gram
dish_footprint_per_100gr = dish_footprint_per_gr * 100

# %%
# add to df
recipes_df['total_footprint'] = dish_footprints
recipes_df['dish_footprint_per_100gr'] = dish_footprint_per_100gr
recipes_df['confidence_score'] = confidence_scores
recipes_df['dietary_info'] = dietary_info_per_dish
recipes_df.head()
# Out:
#            id  ... dietary_info
# 0  000095fc1d  ...   vegetarian
# 1  00051d5b9d  ...   vegetarian
# 2  00059b093b  ...      non-veg
# 3  0005fc89f7  ...      non-veg
# 4  0006ca31f4  ...   vegetarian
#
# [5 rows x 12 columns]

# %%
dish_footprint_per_kilo = dish_footprint_per_100gr * 10
recipes_df['dish_footprint_per_kilo'] = dish_footprint_per_kilo

# %%
# visualize distribution of footprints per kilo
import seaborn as sns
sns.histplot(data=recipes_df['dish_footprint_per_kilo'])

# %%
# check that sum of ingr footprints equals total dish footprint
total = sum(recipes_df['footprint_per_ingr_100gr'][0])
recipes_df['dish_footprint_per_100gr'][0], total
# Out:
# (0.12771783770299366, 0.12771783770299366)

# %% [markdown]
# ## Implement carbon footprint scoring

# %%
# implement co2 scoring
# lower than 2 kilos per kilo = low
# lower than 3 = med
# higher than 3 = high

co2_scores_lst = []

for footprint in dish_footprint_per_kilo:
  if footprint <= 2:
    co2_scores_lst.append('low')
  elif footprint <= 3: 
    co2_scores_lst.append('moderate')
  else:
    co2_scores_lst.append('high')

# %%
recipes_df['co2_score'] = co2_scores_lst
recipes_df.head()
# Out:
#            id  ... co2_score
# 0  000095fc1d  ...       low
# 1  00051d5b9d  ...       low
# 2  00059b093b  ...      high
# 3  0005fc89f7  ...      high
# 4  0006ca31f4  ...       low
#
# [5 rows x 14 columns]

# %%
total_ingredients_count = 0
for i in range(len(ingredient_lst)):
  for n in range(len(ingredient_lst[i])):
    total_ingredients_count += 1
total_ingredients_count
# Out:
# 311435

# %%
# only a very small number of ingredients are not able to be matched to ingredients in our database
false_count= 781
(false_count/total_ingredients_count) * 100
# Out:
# 0.25077463997302807

# %%
recipes_df.columns
# Out:
# Index(['id', 'dish_name', 'ingredients', 'weight_per_ingr', 'url',
#        'total_dish_weight', 'footprints_per_ingredient',
#        'footprint_per_ingr_100gr', 'total_footprint',
#        'dish_footprint_per_100gr', 'confidence_score', 'dietary_info',
#        'dish_footprint_per_kilo', 'co2_score'],
#       dtype='object')

# %% [markdown]
# ## Calculate co2 equivalent to number of km driven

# %% [markdown]
# 1kg = 3.875km

# %%
# co2 equivalent to number of km driven per 100gr

km_driven_per_100gr = dish_footprint_per_100gr * 3.875
recipes_df['km_driven_per_100gr'] = km_driven_per_100gr
recipes_df.head()
# Out:
#            id  ... km_driven_per_100gr
# 0  000095fc1d  ...            0.494907
# 1  00051d5b9d  ...            0.616370
# 2  00059b093b  ...            1.581704
# 3  0005fc89f7  ...            1.436990
# 4  0006ca31f4  ...            0.315985
#
# [5 rows x 15 columns]

# %% [markdown]
# # Add nutritional info

# %%
recipes[0].keys()
# Out:
# dict_keys(['fsa_lights_per100g', 'id', 'ingredients', 'instructions', 'nutr_per_ingredient', 'nutr_values_per100g', 'partition', 'quantity', 'title', 'unit', 'url', 'weight_per_ingr'])

# %%
recipes[0]['nutr_per_ingredient'], recipes[0]['nutr_values_per100g']
# Out:
# ([{'fat': 0.8845044000000001,
#    'nrg': 133.80964,
#    'pro': 23.110512399999998,
#    'sat': 0.26535132,
#    'sod': 81.64656,
#    'sug': 7.348190400000001},
#   {'fat': 0.46,
#    'nrg': 49.0,
#    'pro': 1.02,
#    'sat': 0.023,
#    'sod': 2.0,
#    'sug': 7.43},
#   {'fat': 7.415,
#    'nrg': 149.25,
#    'pro': 4.17,
#    'sat': 1.207,
#    'sod': 8.0,
#    'sug': 6.04}],
#  {'energy': 81.12946131894766,
#   'fat': 2.140139263515891,
#   'protein': 6.914436593565536,
#   'salt': 0.05597816738985967,
#   'saturates': 0.36534716195613937,
#   'sugars': 5.08634103436144})

# %%
# loop through all recipes to make lists of values for each key
nutrients_per_dish_lst = []
for i in range(len(recipes)):
  nutrients_per_dish_lst.append(recipes[i]['nutr_values_per100g'])

len(nutrients_per_dish_lst)
# Out:
# 51235

# %%
co2_df.loc[co2_df['ingredients'] == 'sugar']
# Out:
#      ingredients category dietary_info  CO2_per_kilo  CO2_per_gram
# 3024       sugar    sugar   vegetarian           3.5        0.0035

# %%
recipes_df['nutrients_per_100gr'] = nutrients_per_dish_lst
recipes_df.head()
# Out:
#            id  ...                                nutrients_per_100gr
# 0  000095fc1d  ...  {'energy': 81.12946131894766, 'fat': 2.1401392...
# 1  00051d5b9d  ...  {'energy': 477.09640393594606, 'fat': 23.41248...
# 2  00059b093b  ...  {'energy': 208.05898280960727, 'fat': 14.29704...
# 3  0005fc89f7  ...  {'energy': 194.7525956849092, 'fat': 15.980767...
# 4  0006ca31f4  ...  {'energy': 303.43539955190437, 'fat': 5.094846...
#
# [5 rows x 16 columns]

# %% [markdown]
# ## Add calorie column

# %%
nutrients_per_dish_lst[0]
# Out:
# {'energy': 81.12946131894766,
#  'fat': 2.140139263515891,
#  'protein': 6.914436593565536,
#  'salt': 0.05597816738985967,
#  'saturates': 0.36534716195613937,
#  'sugars': 5.08634103436144}

# %%
import ast

calories_per_dish_lst = []

for i in range(len(nutrients_per_dish_lst)):
  calories_per_dish_lst.append(nutrients_per_dish_lst[i]['energy'])

# mask3 = recipes_df['id'].str.contains(f'{id}', na=True)
# nutrients_dict = ast.literal_eval(recipes_df[mask3].nutrients_per_100gr.item())
# nutrients_dict['energy']

# %%
recipes_df['calories_per_100gr'] = calories_per_dish_lst
recipes_df.head()
# Out:
#            id  ... calories_per_100gr
# 0  000095fc1d  ...          81.129461
# 1  00051d5b9d  ...         477.096404
# 2  00059b093b  ...         208.058983
# 3  0005fc89f7  ...         194.752596
# 4  0006ca31f4  ...         303.435400
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Proportion of ingredient

# %%
proportion_of_ingredients = []

for recipe_number, ingredients in enumerate(ingredient_lst): # get the list of ingredients of each recipe
  ingr_props = []
  for ingr_number, ingredient in enumerate(ingredients): # get each single ingredient
    ingr_prop = (weights_lst[recipe_number][ingr_number] / dish_weights[recipe_number])
    ingr_props.append(ingr_prop)
  proportion_of_ingredients.append(ingr_props)

recipes_df['proportion_of_ingredient'] = proportion_of_ingredients
recipes_df.head()
# Out:
#            id  ...                           proportion_of_ingredient
# 0  000095fc1d  ...  [0.5541124271920566, 0.3713693757085337, 0.074...
# 1  00051d5b9d  ...  [0.13479389772334713, 0.2246564962055785, 0.02...
# 2  00059b093b  ...  [0.8615727229673203, 0.0037988885296359742, 0....
# 3  0005fc89f7  ...  [0.5761976687570326, 0.0476362294273019, 0.096...
# 4  0006ca31f4  ...  [0.19268110530246452, 0.7595220313666916, 0.04...
#
# [5 rows x 18 columns]

# %%
co2_df.sort_values('CO2_per_kilo', ascending=False, inplace=True)
co2_df
# Out:
#             ingredients        category  ... CO2_per_kilo  CO2_per_gram
# 368   blade pork steaks             cow  ...        55.00       0.05500
# 758        chuck steaks             cow  ...        55.00       0.05500
# 2049       minced steak             cow  ...        55.00       0.05500
# 3276   veal round steak             cow  ...        55.00       0.05500
# 3275         veal mince             cow  ...        55.00       0.05500
# ...                 ...             ...  ...          ...           ...
# 1154           eggplant      vegetables  ...         0.09       0.00009
# 3344              water    other_drinks  ...         0.06       0.00006
# 326               beets           fruit  ...         0.05       0.00005
# 2649    roasted seaweed  aquatic plants  ...         0.01       0.00001
# 2761            seaweed  aquatic plants  ...         0.01       0.00001
#
# [3522 rows x 5 columns]

# %%
co2_df['category']
# Out:
# 368                cow
# 758                cow
# 2049               cow
# 3276               cow
# 3275               cow
#              ...
# 1154        vegetables
# 3344      other_drinks
# 326              fruit
# 2649    aquatic plants
# 2761    aquatic plants
# Name: category, Length: 3522, dtype: object

# %%
co2_df.loc[co2_df['category'] == '']
# Out:
# Empty DataFrame
# Columns: [ingredients, category, dietary_info, CO2_per_kilo, CO2_per_gram]
# Index: []

# %%
veg_mask = co2_df['dietary_info'].str.contains(r'vegetarian', na=True)
co2_df.loc[veg_mask].sort_values('CO2_per_kilo', ascending=False)
# Out:
#                                             ingredients  ... CO2_per_gram
# 2810                             shredded asiago cheese  ...      0.01130
# 159                              american cheese slices  ...      0.01130
# 202            athenos traditional crumbled feta cheese  ...      0.01130
# 1772    kraft mexican style finely shredded four cheese  ...      0.01130
# 1773  kraft mexican style shredded four cheese with ...  ...      0.01130
# ...                                                 ...  ...          ...
# 1154                                           eggplant  ...      0.00009
# 3344                                              water  ...      0.00006
# 326                                               beets  ...      0.00005
# 2649                                    roasted seaweed  ...      0.00001
# 2761                                            seaweed  ...      0.00001
#
# [2814 rows x 5 columns]

# %%
co2_df
# Out:
#             ingredients        category  ... CO2_per_kilo  CO2_per_gram
# 368   blade pork steaks             cow  ...        55.00       0.05500
# 758        chuck steaks             cow  ...        55.00       0.05500
# 2049       minced steak             cow  ...        55.00       0.05500
# 3276   veal round steak             cow  ...        55.00       0.05500
# 3275         veal mince             cow  ...        55.00       0.05500
# ...                 ...             ...  ...          ...           ...
# 1154           eggplant      vegetables  ...         0.09       0.00009
# 3344              water    other_drinks  ...         0.06       0.00006
# 326               beets           fruit  ...         0.05       0.00005
# 2649    roasted seaweed  aquatic plants  ...         0.01       0.00001
# 2761            seaweed  aquatic plants  ...         0.01       0.00001
#
# [3522 rows x 5 columns]

# %%
meats_lst = ['beef', 'pork', 'lamb', 'duck', 'chicken', 'salmon']

carbon_output_meats = []
scores_lst = []
for meat in meats_lst:
  carbon_output = co2_df.loc[co2_df['ingredients'] == meat]['CO2_per_kilo'].values[0]
  carbon_output_meats.append(carbon_output)
  scores_lst.append('high')

meats_df = pd.DataFrame(
    {'Food': meats_lst,
     'CO2 Output (kg per kg)': carbon_output_meats,
     'Carbon Footprint': scores_lst
    })
meats_df.sort_values('CO2 Output (kg per kg)', ascending=False, inplace=True)
meats_df
# Out:
#       Food  CO2 Output (kg per kg) Carbon Footprint
# 0     beef                    55.0             High
# 2     lamb                    45.0             High
# 1     pork                    12.1             High
# 3     duck                     5.4             High
# 5   salmon                     5.0             High
# 4  chicken                     4.5             High

# %%
co2_df.loc[co2_df['ingredients'] == 'lettuce']['CO2_per_kilo'].values[0]
# Out:
# 0.6

# %%
co2_scores_lst = []

# %%
nonmeats_lst = ['tofu', 'eggs', 'cheese', 'yogurt', 'tomatoes', 'lettuce', 'bananas']

carbon_output_foods = []
scores_lst = []
for food in nonmeats_lst:
  carbon_output = co2_df.loc[co2_df['ingredients'] == food]['CO2_per_kilo'].values[0]
  carbon_output_foods.append(carbon_output)
  #scores_lst.append('High')
  if carbon_output <= 2:
    scores_lst.append('low')
  elif carbon_output <= 3: 
    scores_lst.append('moderate')
  else:
    scores_lst.append('high')

nonmeats_df = pd.DataFrame(
    {'Food': nonmeats_lst,
     'CO2 Output (kg per kg)': carbon_output_foods,
     'Carbon Footprint': scores_lst
    })
nonmeats_df.sort_values('CO2 Output (kg per kg)', ascending=False, inplace=True)
nonmeats_df
# Out:
#        Food  CO2 Output (kg per kg) Carbon Footprint
# 2    cheese                    11.3             high
# 1      eggs                     3.8             high
# 0      tofu                     2.0              low
# 3    yogurt                     1.5              low
# 4  tomatoes                     1.1              low
# 6   bananas                     0.9              low
# 5   lettuce                     0.6              low

# %%
co2_df.head()
# Out:
#             ingredients category dietary_info  CO2_per_kilo  CO2_per_gram
# 368   blade pork steaks      cow      non-veg          55.0         0.055
# 758        chuck steaks      cow      non-veg          55.0         0.055
# 2049       minced steak      cow      non-veg          55.0         0.055
# 3276   veal round steak      cow      non-veg          55.0         0.055
# 3275         veal mince      cow      non-veg          55.0         0.055

# %% [markdown]
# # Save df to csv

# %%
recipes_df.to_csv('dishes_with_co2_nutrients_4.csv', index=False)

# %%
co2_df.to_csv('co2.csv', index=False)
